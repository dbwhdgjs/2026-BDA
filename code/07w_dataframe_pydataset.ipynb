# %% [markdown]
# <a href="https://colab.research.google.com/github/dbwhdgjs/2026-BDA/blob/main/code/07w_dataframe_pydataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame([[np.nan,2,np.nan,0],[3,4,np.nan,1],[np.nan,np.nan,np.nan,np.nan],[np.nan,3,np.nan,4]],columns = list("ABCD"))
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    """여러 데이터프레임 비교가 쉽게 옆쪽으로 표시한다"""
    html_str=''
    for df in args:
        html_str += df.to_html() + '&nbsp;'*4
    display_html(html_str.replace('table','table style="display:inline"'), raw=True)

# %%
display_side_by_side(df.fillna(10),df)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10.0</td>
#       <td>2.0</td>
#       <td>10.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>10.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10.0</td>
#       <td>3.0</td>
#       <td>10.0</td>
#       <td>4.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
# ...

# %%
df.fillna(10,inplace=True)
df
# Out:
#       A     B     C     D
# 0  10.0   2.0  10.0   0.0
# 1   3.0   4.0  10.0   1.0
# 2  10.0  10.0  10.0  10.0
# 3  10.0   3.0  10.0   4.0

# %% [markdown]
# # pydataset 개요
#
# 데이터셋을 쉽게 메모리에 저장하고 활용할수 있도록 제공되는 패키지
#
# 다양한 테스트용 데이터셋을 포함한다.
# - 데이터 분석이나 시각화 연습등 다양한 용도로 활용.
# - 이러한 데이터셋을 장난감 데이터(toy data)라고도 부름.
#
# 특징
# - 다양한 데이터셋 제공 : 파이썬에서 사용할수 있도록 변환, 빠르게 샘플 데이터 활용 가능.
# - 간편한 데이터 로드 : data()함수 이용해 데이터 로드 간단히가능.
# - 표준화된 데이터 포맷 : 로드한 데이터셋은 **판다스** 데이터 프레임 형태로 변환되어 데이터 분석 및 조작이 용이함.

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 82.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939415 sha256=88c4b612083d80e0e9e9aee2e852df997adb9dd15e1b7a89859668470fcce4de
#   Stored in directory: /root/.cache/pip/wheels/4c/82/ad/f04abc617222b10438b1285ab9b5cfaecd180c10a7c81cff54
# Successfully built pydataset
# ...

# %%
# !pip show pydataset
# Out:
# Name: pydataset
# Version: 0.2.0
# Summary: Provides instant access to many popular datasets right from Python (in dataframe structure).
# Home-page: https://github.com/iamaziz/PyDataset
# Author: Aziz Alto
# Author-email: iamaziz.alto@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: pandas
# Required-by:

# %%
from pydataset import data

all_data = data()
all_data
# Out:
# initiated datasets repo at: /root/.pydataset/
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
all_data[all_data.title.str.contains('titanic')]
# Out:
#      dataset_id       title
# 259     titanic     titanic
# 260  titanicgrp  titanicgrp

# %%
df = data('titanic', show_doc = True) # 데이터셋에 대한 간단한 설명만이 표시됨. 정보 모를떄 사용
df
# Out:
# titanic
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## titanic
#
# ### Description
#
# The data is an observation-based version of the 1912 Titanic passenger
# survival log,
#
# ### Usage
#
#     data(titanic)
#
# ### Format
#
# A data frame with 1316 observations on the following 4 variables.
#
# `class`
#
# a factor with levels `1st class` `2nd class` `3rd class` `crew`
#
# `age`
#
# a factor with levels `child` `adults`
#
# `sex`
#
# a factor with levels `women` `man`
#
# `survived`
#
# a factor with levels `no` `yes`
#
# ### Details
#
# titanic is saved as a data frame. Used to assess risk ratios
#
# ### Source
#
# Found in many other texts
#
# ### References
#
# Hilbe, Joseph M (2014), Modeling Count Data, Cambridge University Press Hilbe,
# Joseph M (2007, 2011), Negative Binomial Regression, Cambridge University
# Press Hilbe, Joseph M (2009), Logistic Regression Models, Chapman & Hall/CRC
#
# ### Examples
#
# ...

# %%
df=data('titanic')
df
# Out:
#           class     age    sex survived
# 1     1st class  adults    man      yes
# 2     1st class  adults    man      yes
# 3     1st class  adults    man      yes
# 4     1st class  adults    man      yes
# 5     1st class  adults    man      yes
# ...         ...     ...    ...      ...
# 1312  3rd class   child  women       no
# 1313  3rd class   child  women       no
# 1314  3rd class   child  women       no
# 1315  3rd class   child  women       no
# 1316  3rd class   child  women       no
#
# [1316 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1316 entries, 1 to 1316
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   class     1316 non-null   object
#  1   age       1316 non-null   object
#  2   sex       1316 non-null   object
#  3   survived  1316 non-null   object
# dtypes: object(4)
# memory usage: 51.4+ KB

# %%
df.describe()
# Out:
#             class     age   sex survived
# count        1316    1316  1316     1316
# unique          3       2     2        2
# top     3rd class  adults   man       no
# freq          706    1207   869      817

# %%
all_data[all_data.title.str.contains('car')] # all_data에서 열 title에 문자열 car을 포함한 행 찾기.
# Out:
#     dataset_id  \
# 382        mpg
#
#                                                                  title
# 382  Fuel economy data from 1999 and 2008 for 38 popular models of car

# %%
df_mpg = data('mpg')
df_mpg
# Out:
#     manufacturer   model  displ  year  cyl  ... drv cty  hwy  fl    class
# 1           audi      a4    1.8  1999    4  ...   f  18   29   p  compact
# 2           audi      a4    1.8  1999    4  ...   f  21   29   p  compact
# 3           audi      a4    2.0  2008    4  ...   f  20   31   p  compact
# 4           audi      a4    2.0  2008    4  ...   f  21   30   p  compact
# 5           audi      a4    2.8  1999    6  ...   f  16   26   p  compact
# ..           ...     ...    ...   ...  ...  ...  ..  ..  ...  ..      ...
# 230   volkswagen  passat    2.0  2008    4  ...   f  19   28   p  midsize
# 231   volkswagen  passat    2.0  2008    4  ...   f  21   29   p  midsize
# 232   volkswagen  passat    2.8  1999    6  ...   f  16   26   p  midsize
# 233   volkswagen  passat    2.8  1999    6  ...   f  18   26   p  midsize
# 234   volkswagen  passat    3.6  2008    6  ...   f  17   26   p  midsize
#
# [234 rows x 11 columns]

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df_mpg['manufacturer'] )
plt.xticks(rotation = 90)
plt.show()

# %%
import pandas as pd
titanic = pd.read_excel("/content/sample_data/titanic.xlsx",index_col=0)
titanic
# Out:
#       pclass  survived  ...   body                        home.dest
# 0          1         1  ...    NaN                     St Louis, MO
# 1          1         1  ...    NaN  Montreal, PQ / Chesterville, ON
# 2          1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# ...      ...       ...  ...    ...                              ...
# 1304       3         0  ...  328.0                              NaN
# 1305       3         0  ...    NaN                              NaN
# 1306       3         0  ...  304.0                              NaN
# 1307       3         0  ...    NaN                              NaN
# 1308       3         0  ...    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
titanic.to_csv("my_titanic.csv")

# %%
tt = pd.read_csv("my_titanic.csv", index_col=0)
tt.head(8)
# Out:
#    pclass  survived  ...   body                        home.dest
# 0       1         1  ...    NaN                     St Louis, MO
# 1       1         1  ...    NaN  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 5       1         1  ...    NaN                     New York, NY
# 6       1         1  ...    NaN                       Hudson, NY
# 7       1         0  ...    NaN                      Belfast, NI
#
# [8 rows x 14 columns]

# %%
import pandas as pd
traffic = pd.read_csv("/content/2022년도시도별교통사고.csv",encoding ='cp949')
traffic
# Out:
#    2022년도 시도별 교통사고 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0               시도    사고건수(건)    사망자수(명)    부상자수(명)
# 1               전국    196,836      2,735    281,803
# 2               서울     33,698        221     45,329
# 3               부산     10,882        113     14,829
# 4               경기     52,968        547     77,377
# 5               강원      6,425        139     10,160
# 6               충북      7,644        149     11,354
# 7               충남      8,164        230     11,964
# 8               전북      5,681        194      8,091
# 9               전남      8,335        201     12,611
# 10              경북     11,037        309     16,189
# 11              경남     10,611        258     14,545
# 12              제주      4,039         53      6,021
# 13              대구     11,102         68     15,721
# 14              인천      7,695         95     10,533
# 15              광주      7,122         58     10,722
# 16              대전      6,841         51      9,850
# ...

# %%
pd.read_csv("/content/2022년도시도별교통사고.csv",encoding='cp949',skiprows=1,index_col=0)
# skiprows  = 1: 위에서 첫줄 무시하고 읽으므로 정상적으로 열명이 ㅈ ㅣ정된 데이터프레임에 저장
# index_col = 0 : index레이블이 기본 정수가 아닌 첫 열 시도를 index레이블로 지정
# Out:
#     사고건수(건) 사망자수(명)  부상자수(명)
# 시도
# 전국  196,836   2,735  281,803
# 서울   33,698     221   45,329
# 부산   10,882     113   14,829
# 경기   52,968     547   77,377
# 강원    6,425     139   10,160
# 충북    7,644     149   11,354
# 충남    8,164     230   11,964
# 전북    5,681     194    8,091
# 전남    8,335     201   12,611
# 경북   11,037     309   16,189
# 경남   10,611     258   14,545
# 제주    4,039      53    6,021
# 대구   11,102      68   15,721
# 인천    7,695      95   10,533
# 광주    7,122      58   10,722
# 대전    6,841      51    9,850
# 울산    3,660      32    5,177
# 세종      932      17    1,330

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   2022년도 시도별 교통사고  19 non-null     object
#  1   Unnamed: 1       19 non-null     object
#  2   Unnamed: 2       19 non-null     object
#  3   Unnamed: 3       19 non-null     object
# dtypes: object(4)
# memory usage: 740.0+ bytes

# %%
import pandas as pd
traffic = pd.read_csv("/content/2022년도시도별교통사고.csv",encoding ='cp949',skiprows=1, index_col=0, thousands=',')

traffic.head()
# Out:
#     사고건수(건)  사망자수(명)  부상자수(명)
# 시도
# 전국   196836     2735   281803
# 서울    33698      221    45329
# 부산    10882      113    14829
# 경기    52968      547    77377
# 강원     6425      139    10160

# %%
traffic[['사망자수(명)']].T
# Out:
# 시도         전국   서울   부산   경기   강원   충북   충남   전북   전남   경북   경남  제주  대구  인천  \
# 사망자수(명)  2735  221  113  547  139  149  230  194  201  309  258  53  68  95
#
# 시도       광주  대전  울산  세종
# 사망자수(명)  58  51  32  17

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 61.9 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(traffic)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(traffic[['사망자수(명)']].T)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(traffic[[traffic.columns[2]]].T)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,3))
sns.barplot(traffic[[traffic.columns[1]]].T)
plt.xticks(rotation=90)
plt.show()
#
